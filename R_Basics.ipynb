# %% [markdown]
# # R Tutorial

# %% [markdown]
# * R is one of the most powerful environments used for data analysis.
# * R is free.
# * R's basic language, is a bit messy to work with.
# * R however, enables us to define functions making our life easier
# * R's community is very large and the members have created astonishing packages.
# * R's packages usually include a set of functions for different purposes.
# * R's packages and their predefined functions save us a great deal of time and let us to stand on the shoulder of a giant.
# * R's package are like invention of wheel and by using them we do not need to reinvent the wheel.
# * Read the article published in nature.
#   + https://www.nature.com/news/programming-tools-adventures-with-r-1.16609
# * There are so many resources on the

# %% [markdown]
# # Install R
# ## Windosw Users:
# * Go to the following link:https://cran.r-project.org/bin/windows/base/
# * Click on the link shown by the red arrow and follow the installation instruction.

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# # Install R
# ## Mac Users:
# * Go to the following link:https://cran.r-project.org/bin/macosx/
# * Click on the link shown by the red and follow the installation instruction.

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# # Anacoda and Jupyter Notebook
# * R environment is not that user friendly, therefore, people usually use RStudio.
# * However, we are going to use Jupyter (using Anaconda) in this course because of the flexibility of Jupyter Notebook
# * We run Jupyter Notebooks through Anaconda.
# * First, we have to download Anaconda (**link**: https://www.anaconda.com/distribution/)
#     + go to the link below the RED arrow if your computer is Mac
#     + go to the link below the BLUE arrow if your computer is Windows

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# * Please follow the links below for full instruction of downloading Anaconda on your computer.
#     + Windows users: https://www.youtube.com/watch?v=18s-NHgLKIA
#     + Mac Users: https://www.youtube.com/watch?v=daVgEXjv6DE

# %% [markdown]
# * When you download and install Anaconda, open the program.
# * Anaconda does not automatically come with R. So you should go to the environments tab (red arrow)

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# * Then create a new environment (click on the tab below the green arrow)

# %% [markdown]
# ![](data:image/png;base64,...)
